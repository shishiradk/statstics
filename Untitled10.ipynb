# %% [markdown]
# <a href="https://colab.research.google.com/github/shishiradk/statstics/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###Outlier

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#define our dataset
dataset=[11,10,12,14,12,15,14,13,15,102,12,14,11,12,13,14,16]

# %%
plt.hist(dataset)
# Out:
# (array([16.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 10. ,  19.2,  28.4,  37.6,  46.8,  56. ,  65.2,  74.4,  83.6,
#          92.8, 102. ]),
#  <BarContainer object of 10 artists>)

# %%
outliers=[]

def detect_outliers(data):
  threshold=3
  mean=np.mean(data)
  std=np.std(data)

  for i in data:
    z_score=(i-mean)/std
    if np.abs(z_score)>threshold:
      outliers.append(i)

      return outliers

# %%
detect_outliers(dataset)
# Out:
# [102]

# %% [markdown]
# #IQR
# 1.Sort the dataset
#
# 2.calculate Q1 and Q3
#
# 3.IQR(q3-q1)
#
# 4.Find the lower fance(q1-1.5(iqr))
#
# 5.find the upper fence(q3+1.5(iqr))

# %%
dataset = sorted(dataset)
dataset
# Out:
# [10, 11, 11, 12, 12, 12, 12, 13, 13, 14, 14, 14, 14, 15, 15, 16, 102]

# %%
q1,q3=np.percentile(dataset,[25,75])

# %%
 print(q1,q3)
# Out:
# 12.0 14.0

# %%
iqr=q3-q1
print(iqr)
# Out:
# 2.0

# %%
lower_fence=q1-(1.5*iqr)
higher_fence=q3+(1.5*iqr)

# %%
print(lower_fence,higher_fence)
# Out:
# 9.0 17.0

# %%
import seaborn as sns

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >
